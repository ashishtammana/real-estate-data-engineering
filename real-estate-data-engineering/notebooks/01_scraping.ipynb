# %%
# 🏡 Real Estate Scraper Notebook 

import pandas as pd

# Load the CSV
df = pd.read_csv('../data/kc_house_data.csv')

# Preview the data
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
import boto3

# MinIO client setup
s3 = boto3.client(
    's3',
    endpoint_url='http://localhost:9000',
    aws_access_key_id='admin',
    aws_secret_access_key='password123',
)

# Upload the Kaggle dataset to MinIO
s3.upload_file('../data/kc_house_data.csv', 'real-estate-data', 'kc_house_data.csv')

print("✅ Kaggle dataset uploaded to MinIO!")
# Out:
# ✅ Kaggle dataset uploaded to MinIO!

# %%
# Check dataset info
df.info()

# Describe numerical features
df.describe()

# Check for missing values
df.isnull().sum()

# Simple price distribution plot
import matplotlib.pyplot as plt

df['price'].hist(bins=50, figsize=(12,6))
plt.title('House Price Distribution')
plt.xlabel('Price')
plt.ylabel('Number of Houses')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# 📊 Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ✅ Load the dataset
df = pd.read_csv('../data/kc_house_data.csv')

# ✅ Quick check of the dataset
print("Shape of dataset:", df.shape)
df.head()
# Out:
# Shape of dataset: (21613, 21)
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# ✅ Check data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# ✅ Check for missing values
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# ✅ Summary statistics
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# ✅ Price distribution
plt.figure(figsize=(12,6))
sns.histplot(df['price'], bins=50, kde=True)
plt.title('House Price Distribution')
plt.xlabel('Price')
plt.ylabel('Number of Houses')
plt.show()

# %%
# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['number'])

# Plot the correlation heatmap
plt.figure(figsize=(15,10))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# ✅ Example scatterplot
plt.figure(figsize=(10,6))
sns.scatterplot(x='sqft_living', y='price', data=df)
plt.title('Price vs. Living Area')
plt.xlabel('Square Feet Living')
plt.ylabel('Price')
plt.show()

# %%
# First, check the date column
df['date'].head()
# Out:
# 0    20141013T000000
# 1    20141209T000000
# 2    20150225T000000
# 3    20141209T000000
# 4    20150218T000000
# Name: date, dtype: object

# %%
# Convert 'date' to datetime format
df['date'] = pd.to_datetime(df['date'], format='%Y%m%dT000000')

# Extract new features from the date
df['year_sold'] = df['date'].dt.year
df['month_sold'] = df['date'].dt.month

# Drop the original 'date' column if you don't need it anymore
df = df.drop(columns=['date'])

# Verify the new features
df[['year_sold', 'month_sold']].head()
# Out:
#    year_sold  month_sold
# 0       2014          10
# 1       2014          12
# 2       2015           2
# 3       2014          12
# 4       2015           2

# %%
# Example: Price per square foot
df['price_per_sqft'] = df['price'] / df['sqft_living']

# Example: Age of the house when sold
df['house_age'] = df['year_sold'] - df['yr_built']

# Example: Renovation age (if applicable)
df['renovation_age'] = df['year_sold'] - df['yr_renovated']
df['renovation_age'] = df['renovation_age'].where(df['yr_renovated'] != 0, 0)

# Verify the new features
df[['price_per_sqft', 'house_age', 'renovation_age']].head()
# Out:
#    price_per_sqft  house_age  renovation_age
# 0      188.050847         59               0
# 1      209.338521         63              23
# 2      233.766234         82               0
# 3      308.163265         49               0
# 4      303.571429         28               0

# %%
# Save the processed dataset
df.to_csv('../data/kc_house_data_processed.csv', index=False)

# Upload to MinIO
import boto3

s3 = boto3.client(
    's3',
    endpoint_url='http://localhost:9000',
    aws_access_key_id='admin',
    aws_secret_access_key='password123',
)

# Upload the file
s3.upload_file('../data/kc_house_data_processed.csv', 'real-estate-data', 'kc_house_data_processed.csv')

print("✅ Processed dataset uploaded to MinIO!")
# Out:
# ✅ Processed dataset uploaded to MinIO!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('../data/kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# Convert 'date' column to datetime
df['date'] = pd.to_datetime(df['date'], format='%Y%m%dT000000')

# Extract year and month sold
df['year_sold'] = df['date'].dt.year
df['month_sold'] = df['date'].dt.month

# Drop the original date column
df.drop(columns=['date'], inplace=True)

# %%
# Price per square foot
df['price_per_sqft'] = df['price'] / df['sqft_living']

# Age of house at sale
df['house_age'] = df['year_sold'] - df['yr_built']

# Renovation age (0 if never renovated)
df['renovation_age'] = df.apply(
    lambda x: x['year_sold'] - x['yr_renovated'] if x['yr_renovated'] != 0 else 0, axis=1
)

# %%
# Missing values check
print(df.isnull().sum())

# Price distribution
plt.figure(figsize=(12,6))
sns.histplot(df['price'], bins=50, kde=True)
plt.title('House Price Distribution')
plt.show()

# Correlation heatmap (only numeric features)
numeric_df = df.select_dtypes(include='number')
plt.figure(figsize=(15,10))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
# Out:
# id                0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# grade             0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# year_sold         0
# month_sold        0
# price_per_sqft    0
# house_age         0
# renovation_age    0
# dtype: int64

# %%
df.to_csv('../data/kc_house_data_processed.csv', index=False)
print("✅ Processed dataset saved.")
# Out:
# ✅ Processed dataset saved.

# %%
import boto3

# MinIO setup
s3 = boto3.client(
    's3',
    endpoint_url='http://localhost:9000',
    aws_access_key_id='admin',
    aws_secret_access_key='password123',
)

# Download the previous file (if exists)
previous_file_path = '../data/kc_house_data_previous.csv'
try:
    s3.download_file('real-estate-data', 'kc_house_data_processed.csv', previous_file_path)
    print("✅ Previous dataset downloaded.")
except:
    print("⚠️ No previous dataset found. Starting fresh.")
# Out:
# ✅ Previous dataset downloaded.

# %%
import pandas as pd

# Load previous data if available
try:
    df_prev = pd.read_csv(previous_file_path)
except FileNotFoundError:
    df_prev = pd.DataFrame()

# Load current processed data
df_current = pd.read_csv('../data/kc_house_data_processed.csv')

# Create a unique fingerprint (e.g., 'id' + 'price')
df_current['fingerprint'] = df_current['id'].astype(str) + "_" + df_current['price'].astype(str)

if not df_prev.empty:
    df_prev['fingerprint'] = df_prev['id'].astype(str) + "_" + df_prev['price'].astype(str)

    # Detect new or changed properties
    changes = df_current[~df_current['fingerprint'].isin(df_prev['fingerprint'])]
    print(f"🔍 {len(changes)} new or updated properties found.")
else:
    changes = df_current
    print("🚀 First run, treating all records as new.")
# Out:
# 🔍 0 new or updated properties found.

# %%
# Save current data as the new "previous"
df_current.to_csv('../data/kc_house_data_previous.csv', index=False)

# Upload to MinIO
s3.upload_file('../data/kc_house_data_previous.csv', 'real-estate-data', 'kc_house_data_processed.csv')
print("✅ Updated dataset uploaded to MinIO.")
# Out:
# ✅ Updated dataset uploaded to MinIO.

# %%
from dagster import job, op

# %%
from dagster import job, op
import pandas as pd
import boto3

@op
def load_data():
    return pd.read_csv('../data/kc_house_data_processed.csv')

@op
def apply_cdc(df_current):
    s3 = boto3.client(
        's3',
        endpoint_url='http://localhost:9000',
        aws_access_key_id='admin',
        aws_secret_access_key='password123',
    )
    try:
        s3.download_file('real-estate-data', 'kc_house_data_processed.csv', '../data/kc_house_data_previous.csv')
        df_prev = pd.read_csv('../data/kc_house_data_previous.csv')
        df_current['fingerprint'] = df_current['id'].astype(str) + "_" + df_current['price'].astype(str)
        df_prev['fingerprint'] = df_prev['id'].astype(str) + "_" + df_prev['price'].astype(str)
        changes = df_current[~df_current['fingerprint'].isin(df_prev['fingerprint'])]
        print(f"🔍 {len(changes)} changes detected.")
    except:
        changes = df_current
        print("🚀 First run, all records are new.")
    return df_current

@op
def save_and_upload(df):
    df.to_csv('../data/kc_house_data_previous.csv', index=False)
    s3 = boto3.client(
        's3',
        endpoint_url='http://localhost:9000',
        aws_access_key_id='admin',
        aws_secret_access_key='password123',
    )
    s3.upload_file('../data/kc_house_data_previous.csv', 'real-estate-data', 'kc_house_data_processed.csv')
    print("✅ Dataset updated in MinIO.")

@job
def real_estate_pipeline():
    df = load_data()
    updated_df = apply_cdc(df)
    save_and_upload(updated_df)
